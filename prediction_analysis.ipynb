# %%
import os # for file paths
import numpy as np # for linear algebra
import pandas as pd # for data processing
import xgboost as xgb # for Gradient Boost
import matplotlib.pyplot as plt # for plotting
from xgboost import plot_importance, plot_tree # XBoost for plotting
from sklearn.metrics import mean_squared_error  # for error calculation
from sklearn.preprocessing import MinMaxScaler # for normalization
from sklearn.model_selection import train_test_split, GridSearchCV # for splitting data

# Chart drawing
import plotly as py # for chart drawing interactive
import plotly.io as pio # for chart drawing interactive
import plotly.graph_objects as go # for chart drawing interactive
from plotly.subplots import make_subplots # for chart drawing interactive

# Mute sklearn warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=DeprecationWarning)

# %%
df = pd.read_csv('dataset_train.csv', parse_dates=['Date'])
df['Date'] = (pd.Timestamp('now') - pd.to_datetime(df['Date'])).dt.total_seconds()
df.head()
# Out:
#            Date    Open    High     Low   Close  Volume  OpenInt
# 0  4.057139e+08  24.333  24.333  23.946  23.946   43321        0
# 1  4.056275e+08  24.644  24.644  24.362  24.487   18031        0
# 2  4.055411e+08  24.759  24.759  24.314  24.507    8897        0
# 3  4.052819e+08  24.624  24.624  24.449  24.595   19443        0
# 4  4.051955e+08  24.477  24.517  24.431  24.517    8456        0

# %%
# train closing valume
df['Close'].plot(figsize=(16,4),legend=True)
plt.title('Closing price')
# Out:
# Text(0.5, 1.0, 'Closing price')

# %%
# convert Date col to ordinal
X = df.index.values.reshape(-1,1)
y = df[['Close']]

# %%
df['Close'].values
# Out:
# array([23.946 , 24.487 , 24.507 , ..., 57.49  , 56.9265, 56.4   ])

# %%
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
from forecast_tool import forecast_plot as fp
df = fp.get_data()
df = pd.read_csv('dataset_train.csv', parse_dates=['Date'])
period = 'y' #[y, m, d] 
date='Date'
newtarget='Volume'
fp.overall_vis(df, date, newtarget, period, 'Close')
# Out:
# The date interval for each data points is the same, of 'year' interval
# Calibrating best ARIMA
# Optimised:  ARIMA(0,0,0)(0,0,0)[0] intercept
